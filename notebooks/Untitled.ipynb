# %%
import pandas as pd

# %%
df = pd.read_parquet("../data/vdem_subset_1970_nomean_strfix.parquet")

# %%
df.head()
df.shape
# Out:
# (1472, 4341)

# %%
df.tail()
# Out:
#      country_name country_text_id  country_id  year historical_date  project  \
# 1467      Hungary             HUN         210  2020      2020-12-31        0
# 1468      Hungary             HUN         210  2021      2021-12-31        0
# 1469      Hungary             HUN         210  2022      2022-12-31        0
# 1470      Hungary             HUN         210  2023      2023-12-31        0
# 1471      Hungary             HUN         210  2024      2024-12-31        0
#
#       historical histname  codingstart  codingend  ...  e_mipopula  \
# 1467           1  Hungary         1789       2024  ...         NaN
# 1468           1  Hungary         1789       2024  ...         NaN
# 1469           1  Hungary         1789       2024  ...         NaN
# 1470           1  Hungary         1789       2024  ...         NaN
# 1471           1  Hungary         1789       2024  ...         NaN
#
#       e_miurbani  e_pefeliex   e_wb_pop  e_pechmor  e_miinteco  e_civil_war  \
# ...
